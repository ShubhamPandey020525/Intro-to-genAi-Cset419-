# %%
dataset_choice = "fashion"
epochs = 100
batch_size = 128
noise_dim = 100
learning_rate = 0.0002
save_interval = 5

import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)
# Out:
# Device: cuda

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

img_size = 28
channels = 1

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

if dataset_choice == "mnist":
    dataset = datasets.MNIST("./data", train=True, download=True, transform=transform)
else:
    dataset = datasets.FashionMNIST("./data", train=True, download=True, transform=transform)

dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
print("Dataset loaded:", dataset_choice)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 12.8MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 205kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.82MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 14.6MB/s]
# Dataset loaded: fashion

# %%
import torch.nn as nn

class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(noise_dim, 256),
            nn.LeakyReLU(0.2),

            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),

            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),

            nn.Linear(1024, img_size * img_size),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img.view(z.size(0), channels, img_size, img_size)


class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(img_size * img_size, 512),
            nn.LeakyReLU(0.2),

            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),

            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img):
        return self.model(img.view(img.size(0), -1))


generator = Generator().to(device)
discriminator = Discriminator().to(device)
print("Models initialized")
# Out:
# Models initialized

# %%
import torch.optim as optim

criterion = nn.BCELoss()

optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate, betas=(0.5, 0.999))

# %%
import os
import torchvision.utils as vutils
import torch.nn.functional as F

os.makedirs("generated_samples", exist_ok=True)

best_g_loss = float("inf")
best_epoch = -1

for epoch in range(1, epochs + 1):
    for real_imgs, _ in dataloader:
        real_imgs = real_imgs.to(device)
        bs = real_imgs.size(0)

        # ----- LABEL SMOOTHING -----
        real_labels = torch.full((bs, 1), 0.9, device=device)
        fake_labels = torch.zeros(bs, 1, device=device)

        # ----- TRAIN DISCRIMINATOR -----
        optimizer_D.zero_grad()

        real_loss = criterion(discriminator(real_imgs), real_labels)

        z = torch.randn(bs, noise_dim, device=device)
        fake_imgs = generator(z)
        fake_loss = criterion(discriminator(fake_imgs.detach()), fake_labels)

        d_loss = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_D.step()

        # ----- TRAIN GENERATOR -----
        optimizer_G.zero_grad()
        g_loss = criterion(discriminator(fake_imgs), real_labels)
        g_loss.backward()
        optimizer_G.step()

    # ----- LOG -----
    print(f"Epoch {epoch}/{epochs} | D_loss: {d_loss.item():.2f} | G_loss: {g_loss.item():.2f}")

    # ----- SAVE BEST MODEL -----
    if g_loss.item() < best_g_loss:
        best_g_loss = g_loss.item()
        best_epoch = epoch
        torch.save(generator.state_dict(), "best_generator.pth")
        torch.save(discriminator.state_dict(), "best_discriminator.pth")
        print(f" Best model saved at epoch {epoch}")

    # ----- SAVE BIG, CLEAR IMAGES -----
    if epoch % save_interval == 0:
        with torch.no_grad():
            z = torch.randn(25, noise_dim, device=device)
            samples = generator(z)
            samples = (samples + 1) / 2
            samples = F.interpolate(samples, scale_factor=4, mode="nearest")

            vutils.save_image(
                samples,
                f"generated_samples/epoch_{epoch:02d}.png",
                nrow=5,
                padding=2
            )
# Out:
# Epoch 1/100 | D_loss: 0.52 | G_loss: 2.43
#  Best model saved at epoch 1
# Epoch 2/100 | D_loss: 0.47 | G_loss: 1.70
#  Best model saved at epoch 2
# Epoch 3/100 | D_loss: 0.59 | G_loss: 1.26
#  Best model saved at epoch 3
# Epoch 4/100 | D_loss: 0.53 | G_loss: 1.46
# Epoch 5/100 | D_loss: 0.52 | G_loss: 1.36
# Epoch 6/100 | D_loss: 0.60 | G_loss: 1.75
# Epoch 7/100 | D_loss: 0.59 | G_loss: 1.15
#  Best model saved at epoch 7
# Epoch 8/100 | D_loss: 0.58 | G_loss: 1.44
# Epoch 9/100 | D_loss: 0.59 | G_loss: 1.15
# Epoch 10/100 | D_loss: 0.58 | G_loss: 1.20
# Epoch 11/100 | D_loss: 0.65 | G_loss: 0.88
#  Best model saved at epoch 11
# Epoch 12/100 | D_loss: 0.63 | G_loss: 0.98
# Epoch 13/100 | D_loss: 0.61 | G_loss: 1.19
# Epoch 14/100 | D_loss: 0.68 | G_loss: 0.86
#  Best model saved at epoch 14
# Epoch 15/100 | D_loss: 0.61 | G_loss: 1.06
# Epoch 16/100 | D_loss: 0.68 | G_loss: 0.92
# Epoch 17/100 | D_loss: 0.62 | G_loss: 1.05
# Epoch 18/100 | D_loss: 0.61 | G_loss: 1.13
# Epoch 19/100 | D_loss: 0.64 | G_loss: 1.15
# Epoch 20/100 | D_loss: 0.65 | G_loss: 0.96
# Epoch 21/100 | D_loss: 0.63 | G_loss: 1.03
# Epoch 22/100 | D_loss: 0.67 | G_loss: 1.03
# Epoch 23/100 | D_loss: 0.66 | G_loss: 0.90
# Epoch 24/100 | D_loss: 0.65 | G_loss: 0.90
# Epoch 25/100 | D_loss: 0.65 | G_loss: 1.06
# Epoch 26/100 | D_loss: 0.65 | G_loss: 1.05
# Epoch 27/100 | D_loss: 0.70 | G_loss: 0.90
# Epoch 28/100 | D_loss: 0.66 | G_loss: 1.12
# Epoch 29/100 | D_loss: 0.67 | G_loss: 1.06
# Epoch 30/100 | D_loss: 0.64 | G_loss: 0.97
# Epoch 31/100 | D_loss: 0.65 | G_loss: 0.92
# Epoch 32/100 | D_loss: 0.69 | G_loss: 0.93
# Epoch 33/100 | D_loss: 0.66 | G_loss: 1.06
# Epoch 34/100 | D_loss: 0.67 | G_loss: 0.85
#  Best model saved at epoch 34
# Epoch 35/100 | D_loss: 0.64 | G_loss: 1.12
# Epoch 36/100 | D_loss: 0.67 | G_loss: 0.90
# Epoch 37/100 | D_loss: 0.70 | G_loss: 0.89
# Epoch 38/100 | D_loss: 0.66 | G_loss: 0.86
# Epoch 39/100 | D_loss: 0.67 | G_loss: 0.97
# Epoch 40/100 | D_loss: 0.65 | G_loss: 0.93
# Epoch 41/100 | D_loss: 0.64 | G_loss: 0.95
# Epoch 42/100 | D_loss: 0.67 | G_loss: 0.95
# Epoch 43/100 | D_loss: 0.67 | G_loss: 0.91
# Epoch 44/100 | D_loss: 0.66 | G_loss: 0.92
# Epoch 45/100 | D_loss: 0.67 | G_loss: 0.91
# Epoch 46/100 | D_loss: 0.66 | G_loss: 0.99
# Epoch 47/100 | D_loss: 0.67 | G_loss: 0.97
# Epoch 48/100 | D_loss: 0.68 | G_loss: 0.86
# Epoch 49/100 | D_loss: 0.64 | G_loss: 0.95
# Epoch 50/100 | D_loss: 0.67 | G_loss: 0.89
# Epoch 51/100 | D_loss: 0.68 | G_loss: 1.00
# Epoch 52/100 | D_loss: 0.66 | G_loss: 0.97
# Epoch 53/100 | D_loss: 0.65 | G_loss: 0.97
# Epoch 54/100 | D_loss: 0.71 | G_loss: 1.01
# Epoch 55/100 | D_loss: 0.66 | G_loss: 0.92
# Epoch 56/100 | D_loss: 0.65 | G_loss: 0.90
# Epoch 57/100 | D_loss: 0.66 | G_loss: 0.93
# Epoch 58/100 | D_loss: 0.65 | G_loss: 1.02
# Epoch 59/100 | D_loss: 0.68 | G_loss: 0.88
# Epoch 60/100 | D_loss: 0.69 | G_loss: 0.88
# Epoch 61/100 | D_loss: 0.65 | G_loss: 0.99
# Epoch 62/100 | D_loss: 0.67 | G_loss: 0.84
#  Best model saved at epoch 62
# Epoch 63/100 | D_loss: 0.64 | G_loss: 0.93
# Epoch 64/100 | D_loss: 0.64 | G_loss: 0.98
# Epoch 65/100 | D_loss: 0.71 | G_loss: 0.94
# Epoch 66/100 | D_loss: 0.64 | G_loss: 0.96
# Epoch 67/100 | D_loss: 0.66 | G_loss: 0.95
# Epoch 68/100 | D_loss: 0.66 | G_loss: 0.92
# Epoch 69/100 | D_loss: 0.64 | G_loss: 1.07
# Epoch 70/100 | D_loss: 0.67 | G_loss: 0.91
# Epoch 71/100 | D_loss: 0.66 | G_loss: 0.91
# Epoch 72/100 | D_loss: 0.66 | G_loss: 1.02
# Epoch 73/100 | D_loss: 0.66 | G_loss: 0.94
# Epoch 74/100 | D_loss: 0.64 | G_loss: 0.94
# Epoch 75/100 | D_loss: 0.64 | G_loss: 0.87
# Epoch 76/100 | D_loss: 0.65 | G_loss: 0.93
# Epoch 77/100 | D_loss: 0.65 | G_loss: 0.90
# Epoch 78/100 | D_loss: 0.63 | G_loss: 0.97
# Epoch 79/100 | D_loss: 0.64 | G_loss: 1.04
# Epoch 80/100 | D_loss: 0.69 | G_loss: 0.89
# Epoch 81/100 | D_loss: 0.70 | G_loss: 0.91
# Epoch 82/100 | D_loss: 0.63 | G_loss: 1.01
# Epoch 83/100 | D_loss: 0.66 | G_loss: 0.96
# Epoch 84/100 | D_loss: 0.65 | G_loss: 1.08
# Epoch 85/100 | D_loss: 0.66 | G_loss: 0.93
# Epoch 86/100 | D_loss: 0.67 | G_loss: 0.91
# Epoch 87/100 | D_loss: 0.63 | G_loss: 1.01
# Epoch 88/100 | D_loss: 0.63 | G_loss: 0.98
# Epoch 89/100 | D_loss: 0.67 | G_loss: 0.97
# Epoch 90/100 | D_loss: 0.64 | G_loss: 1.00
# Epoch 91/100 | D_loss: 0.65 | G_loss: 1.00
# Epoch 92/100 | D_loss: 0.64 | G_loss: 1.07
# Epoch 93/100 | D_loss: 0.64 | G_loss: 1.00
# Epoch 94/100 | D_loss: 0.68 | G_loss: 0.92
# Epoch 95/100 | D_loss: 0.64 | G_loss: 1.05
# Epoch 96/100 | D_loss: 0.64 | G_loss: 0.99
# Epoch 97/100 | D_loss: 0.64 | G_loss: 1.00
# Epoch 98/100 | D_loss: 0.65 | G_loss: 0.95
# Epoch 99/100 | D_loss: 0.65 | G_loss: 0.95
# Epoch 100/100 | D_loss: 0.65 | G_loss: 0.96

# %%
print("Training complete")
print("Best epoch:", best_epoch)
print("Best Generator Loss:", best_g_loss)
# Out:
# Training complete
# Best epoch: 62
# Best Generator Loss: 0.8399407267570496
